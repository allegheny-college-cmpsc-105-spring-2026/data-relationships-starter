# %% [markdown]
# TODO: Click on the badge, then `Copy to Drive` before continuing.

# %% [markdown]
# TODO: double click and replace this text with your name

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/data-relationships-starter/blob/main/data_relationships_starter.ipynb)

# %% [markdown]
# # Data Relationships Lab

# %% [markdown]
# A common question in data analysis is whether two variables are related to each other. In this lab you will explore
# a large dataset on your own to find interesting relationships. This lab is based largely on the course materials and
# activity found under week 12 & week 13.
# Feel free to reference these materials and any earlier labs as needed.
#
# ## Goals
#
# Your goals for this lab are:
#
# - come up with a hypothesized relationship
# - calculate slopes and intercepts by hand
# - confirm calculations with scipy (linregress and pearsonr)
# - plot fit lines on top of data
#
# Don't forget to answer all `T O D O` markers and to remove the markers.
#
# ## Deadline
#
# This lab should be completed during the lab meeting time, but modifications may be made until the official deadline of 4:15pm on April 14.
#
# ## Learning Outcomes
#
# By completing this lab you will
#
# - practice linear modeling
# - evaluate linear models
# - narrate your thought process connecting your hypothesis to your actual exploration / evaluation.
#
# ## Reminders
#
# - If needed, one of four available automatic extension **tokens** can be applied by using the form on the course syllabus.
# - Refer to previous materials to learn how to use Notebooks in Google Colab, make your work accessible, submit, and check your work.
#
# ## Saving Your Work
#
# Saving your work and making it accessible is a required part of all labs.
#
# ### Accessability Part 1
#
# Update the Colab filename to be `data_relationships.ipynb`.
#
# Make sure that all cells have been executed and are SHOWING their outputs.
#
# ### Saving
#
# I would recommend a workflow of `Copy to Drive --> editing/running/testing --> downloading`. You should have already hit `Copy to Drive`, but if you haven't, then please do so now. Then go ahead and download the file from the menu at the top of the Colab interface. File > Download > Download ipynb
#
# ### Accessibility Part 2
#
# If you are satisfied with your work, you can now upload the downloaded file to your GitHub repo!
#
# - Use GitHub to upload the file.
#   - Next to the green code button in GitHub, you will see an `add file` button. Click that, then choose the downloaded notebook from your computer.
#
# ## Checking Your Work
#
# ### Check your file output
#
# Once your file is uploaded, please open it on GitHub. All the outputs and plots should be showing. If they are not showing, this means that not all code cells were executed before you downloaded your file.
#
# ### Check GitHub Actions
#
# In GitHub, go to the Actions tab. Click on the top Action to see a report about your T O D Os. If the T O D Os have been done and deleted, then the actions will show that gatorgrade reports 100%. This is not your grade, but it is a good indication that you did not forget to do something.
#
# If you see remaining T O D Os, then you may want to edit and update your file.

# %% [markdown]
# ## Getting Started

# %%
# TODO: import pandas, scipy, matplotlib.pyplot, numpy

# %%
# TODO: run this code cell

df = pd.read_csv("https://raw.githubusercontent.com/allegheny-college-cmpsc-105-spring-2026/data-relationships-starter/main/data/data-analysis-kaggle-song-popularity-data.csv")

df

# %%
### Please answer these questions before continuing.

# TODO: How many rows of data are there for df (HINT: The answer is not 5)
# TODO: How many columns of data are there for df
# TODO: What are the column names?

# %%
# TODO: Come up with a hypothesis to explore, or choose one below.

# For example:
# for songs that are in major keys, is danceability related to tempo?
# for songs that are in minor keys, is danceability related to tempo?

# %%
# OPTIONAL: do any wrangling you like as needed to simplify variable names or convert units.
# This is optional, as needed

# %%
# TODO: Compute slope, intercept, and R_squared by hand

# %%
# TODO: Check your hand calculations with scipy linregress and pearsonr

# %%
# TODO: Plot your data and the line you found on top
# TODO: Be sure to label axes, with units if applicable, and title the figure

# %% [markdown]
# # Report

# %% [markdown]
# ### What this was lab about
#
# TODO: Briefly summarize what this lab was about and what you did at a high level.
# TODO: Include your hypothesis.
#
# ### Methods
#
# TODO: Briefly talk about the methods you used to explore the data and any specific functions that helped reveal the patterns.
#
# ### What was found
#
# TODO: Briefly restate what you found out by exploring the data. Please refer to the figures you made above. For example, "As shown in figure 1..."
# TODO: Be sure to report the linear regression values of slope, intercept, R_squared, and probability.
# TODO: Connect what you found back to your original hypothesis. Was it supported?
#
# ### Future directions
#
# TODO: Briefly state what could be explored within the data in the future, building on what you already did. Your answer must be something that you could actually do with the data, related to this lab.
